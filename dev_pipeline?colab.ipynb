# %% [markdown]
# <a href="https://colab.research.google.com/github/mehmetcandfx/Memosoft/blob/main/dev_pipeline%3Fcolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
